# %% [markdown]
# # Importing Libraries

# %%
import itertools
import sys
import time
import numpy as np
import pandas as pd

# %%
from pip._vendor.distlib.compat import raw_input

# %% [markdown]
# # Loading the datasets

# %%
print("Welcome to apriori algorithms. \n Please choose the dataSet you want: \n 1. test \n 2. t2 \n 3. t3 \n 4. t4 \n 5. t5")
while True:
    choice_of_data=input()
    if(choice_of_data=='1'):
        data=pd.read_csv(r'C:\Masters\2nd Semester\Data Mining\test.txt')
        break
    elif(choice_of_data=='2'):
        data=pd.read_csv(r'C:\Masters\2nd Semester\Data Mining\t2.txt')
        break
    elif(choice_of_data=='3'):
        data=pd.read_csv(r'C:\Masters\2nd Semester\Data Mining\t3.txt')
        break
    elif(choice_of_data=='4'):
        data=pd.read_csv(r'C:\Masters\2nd Semester\Data Mining\t4.txt')
        break
    elif(choice_of_data=='5'):
        data=pd.read_csv(r'C:\Masters\2nd Semester\Data Mining\t5.txt')
        break
    else:
        print("Invalid data, please enter the valid data")
        break
# Out:
# Welcome to apriori algorithms.
#  Please choose the dataSet you want:
#  1. test
#  2. t2
#  3. t3
#  4. t4
#  5. t5
# 1

# %% [markdown]
# # Entering the Minimum Support, Minimum Confidence and Minimum Lift

# %%
min_support = float(raw_input("Enter the minimum support - range(0-1): "))
min_confidence = float(raw_input("Enter the minimum confidence - range (0-1): "))
min_lift = float(raw_input("Enter the minimum lift (min_lift): "))
# Out:
# Enter the minimum support - range(0-1): 0.30
# Enter the minimum confidence - range (0-1): 0.70
# Enter the minimum lift (min_lift): 3

# %%
C1 = {}
transactions = 0
D = []
T = []

# %%
#def transactions(dataList):
    #Transactions = []
    #df_items = dataList['TransactionList']
    #comma_splitted_df = df_items.apply(lambda x: x.split(','))
    #for i in comma_splitted_df:
    #    Transactions.append(i)
    #return Transactions
    #load_transactions(dataList)
for line in data:
    T = []
    transactions += 1
    for word in line.split():
        T.append(word)
        if word not in C1.keys():
            C1[word] = 1
        else:
            count = C1[word]
            C1[word] = count + 1
    D.append(T)

# %% [markdown]
# # Frequent 1-ITEMSET

# %%
L1 = []
for key in C1:
    if (C1[key] / transactions) >= min_support:
        list = [key]
        L1.append(list)
print("----------------------FREQUENT 1-ITEMSET-------------------------")
print(L1)
print("-----------------------------------------------------------------")
# Out:
# ----------------------FREQUENT 1-ITEMSET-------------------------
# [['milk'], ['sugar'], ['bread'], ['toast'], ['crisp'], ['apple'], ['banana'], ['grapes'], ['curd'], ['cheese'], ['butter'], ['mango']]
# -----------------------------------------------------------------

# %% [markdown]
# # Apriori Function

# %%
def apriori_gen(Lk_1, k):
    length = k
    Ck = []
    for list1 in Lk_1:
        for list2 in Lk_1:
            count = 0
            c = []
            if list1 != list2:
                while count < length - 1:
                    if list1[count] != list2[count]:
                        break
                    else:
                        count += 1
                else:
                    if list1[length - 1] < list2[length - 1]:
                        for item in list1:
                            c.append(item)
                        c.append(list2[length - 1])
                        if not has_infrequent_subset(c, Lk_1, k):
                            Ck.append(c)
    return Ck

# %%
def find_subsets(c, k):
    return set(itertools.combinations(c, k))

# %%
def has_infrequent_subset(c, Lk_1, k):
    list = find_subsets(c, k)
    for item in list:
        s = []
        for l in item:
            s.append(l)
        s.sort()
        if s not in Lk_1:
            return True
    return False

# %% [markdown]
# # Frequent Itemsets Function

# %%
def frequent_itemsets():
    k = 2
    Lk_1 = []
    L = []
    for item in L1:
        Lk_1.append(item)
    while Lk_1:
        Lk = []
        Ck = apriori_gen(Lk_1, k - 1)
        for c in Ck:
            count = 0
            transactions = 0
            s = set(c)
            for T in D:
                transactions += 1
                t = set(T)
                if s.issubset(t):
                    count += 1
            if (count / transactions) >= min_support:
                c.sort()
                Lk.append(c)
        Lk_1 = []
        print("----------------------FREQUENT %d-ITEMSET-------------------------" % k)
        print(Lk)
        print("------------------------------------------------------------------")
        for l in Lk:
            Lk_1.append(l)
        k += 1
        if Lk:
            L.append(Lk)

    return L

# %% [markdown]
# # Generate Association Rules

# %%
def generate_association_rules():
    num = 1
    L = frequent_itemsets()
    print("--------------------ASSOCIATION RULES-------------------")
    print("")
    print("RULE \t \t \t       SUPP      CONF      LIFT")
    print("--------------------------------------------------------")
    for itemset in L:
        for l in itemset:
            length = len(l)
            count = 1
            while count < length:
                r = find_subsets(l, count)
                count += 1
                for item in r:
                    T_supporting_A = 0
                    T_supporting_B = 0
                    T_supporting_AB = 0
                    s = []
                    m = []
                    for i in item:
                        s.append(i)
                    for T in D:
                        if set(s).issubset(set(T)):
                            T_supporting_A += 1
                            if set(l).issubset(set(T)):
                                T_supporting_AB += 1
                        if set(l).issubset(set(T)):
                            T_supporting_B += 1

                            suppAB = T_supporting_AB / len(D)
                            confAB = T_supporting_AB / T_supporting_A
                            liftAB = confAB / (T_supporting_B / len(D))

                    if confAB >= min_confidence and liftAB >= min_lift:
                        for index in l:
                            if index not in s:
                                m.append(index)

                        print("Rule #%d : %s ==> %s   %f  %f  %f" % (num, s, m, suppAB, confAB, liftAB))
                        num += 1


generate_association_rules()

print("--------------------------------------------------------")
# Out:
# ----------------------FREQUENT 2-ITEMSET-------------------------
# [['milk', 'sugar'], ['milk', 'toast'], ['sugar', 'toast'], ['bread', 'milk'], ['bread', 'sugar'], ['bread', 'toast'], ['bread', 'crisp'], ['bread', 'grapes'], ['bread', 'curd'], ['bread', 'cheese'], ['bread', 'butter'], ['bread', 'mango'], ['crisp', 'milk'], ['crisp', 'sugar'], ['crisp', 'toast'], ['crisp', 'grapes'], ['crisp', 'curd'], ['crisp', 'mango'], ['apple', 'milk'], ['apple', 'sugar'], ['apple', 'bread'], ['apple', 'toast'], ['apple', 'crisp'], ['apple', 'banana'], ['apple', 'grapes'], ['apple', 'curd'], ['apple', 'cheese'], ['apple', 'butter'], ['apple', 'mango'], ['banana', 'milk'], ['banana', 'sugar'], ['banana', 'bread'], ['banana', 'toast'], ['banana', 'crisp'], ['banana', 'grapes'], ['banana', 'curd'], ['banana', 'cheese'], ['banana', 'butter'], ['banana', 'mango'], ['grapes', 'milk'], ['grapes', 'sugar'], ['grapes', 'toast'], ['grapes', 'mango'], ['curd', 'milk'], ['curd', 'sugar'], ['curd', 'toast'], ['curd', 'grapes'], ['curd', 'mango'], ['cheese', 'milk'], ['cheese', 'sugar'], ['cheese', 'toast'], ['cheese', 'crisp'], ['cheese', 'grapes'], ['cheese', 'curd'], ['cheese', 'mango'], ['butter', 'milk'], ['butter', 'sugar'], ['butter', 'toast'], ['butter', 'crisp'], ['butter', 'grapes'], ['butter', 'curd'], ['butter', 'cheese'], ['butter', 'mango'], ['mango', 'milk'], ['mango', 'sugar'], ['mango', 'toast']]
# ------------------------------------------------------------------
# ----------------------FREQUENT 3-ITEMSET-------------------------
# [['milk', 'sugar', 'toast'], ['bread', 'milk', 'sugar'], ['bread', 'milk', 'toast'], ['bread', 'sugar', 'toast'], ['bread', 'crisp', 'milk'], ['bread', 'crisp', 'sugar'], ['bread', 'crisp', 'toast'], ['bread', 'crisp', 'grapes'], ['bread', 'crisp', 'curd'], ['bread', 'crisp', 'mango'], ['bread', 'grapes', 'milk'], ['bread', 'grapes', 'sugar'], ['bread', 'grapes', 'toast'], ['bread', 'grapes', 'mango'], ['bread', 'curd', 'milk'], ['bread', 'curd', 'sugar'], ['bread', 'curd', 'toast'], ['bread', 'curd', 'grapes'], ['bread', 'curd', 'mango'], ['bread', 'cheese', 'milk'], ['bread', 'cheese', 'sugar'], ['bread', 'cheese', 'toast'], ['bread', 'cheese', 'crisp'], ['bread', 'cheese', 'grapes'], ['bread', 'cheese', 'curd'], ['bread', 'cheese', 'mango'], ['bread', 'butter', 'milk'], ['bread', 'butter', 'sugar'], ['bread', 'butter', 'toast'], ['bread', 'butter', 'crisp'], ['bread', 'butter', 'grapes'], ['bread', 'butter', 'curd'], ['bread', 'butter', 'cheese'], ['bread', 'butter', 'mango'], ['bread', 'mango', 'milk'], ['bread', 'mango', 'sugar'], ['bread', 'mango', 'toast'], ['crisp', 'milk', 'sugar'], ['crisp', 'milk', 'toast'], ['crisp', 'sugar', 'toast'], ['crisp', 'grapes', 'milk'], ['crisp', 'grapes', 'sugar'], ['crisp', 'grapes', 'toast'], ['crisp', 'grapes', 'mango'], ['crisp', 'curd', 'milk'], ['crisp', 'curd', 'sugar'], ['crisp', 'curd', 'toast'], ['crisp', 'curd', 'grapes'], ['crisp', 'curd', 'mango'], ['crisp', 'mango', 'milk'], ['crisp', 'mango', 'sugar'], ['crisp', 'mango', 'toast'], ['apple', 'milk', 'sugar'], ['apple', 'milk', 'toast'], ['apple', 'sugar', 'toast'], ['apple', 'bread', 'milk'], ['apple', 'bread', 'sugar'], ['apple', 'bread', 'toast'], ['apple', 'bread', 'crisp'], ['apple', 'bread', 'grapes'], ['apple', 'bread', 'curd'], ['apple', 'bread', 'cheese'], ['apple', 'bread', 'butter'], ['apple', 'bread', 'mango'], ['apple', 'crisp', 'milk'], ['apple', 'crisp', 'sugar'], ['apple', 'crisp', 'toast'], ['apple', 'crisp', 'grapes'], ['apple', 'crisp', 'curd'], ['apple', 'crisp', 'mango'], ['apple', 'banana', 'milk'], ['apple', 'banana', 'sugar'], ['apple', 'banana', 'bread'], ['apple', 'banana', 'toast'], ['apple', 'banana', 'crisp'], ['apple', 'banana', 'grapes'], ['apple', 'banana', 'curd'], ['apple', 'banana', 'cheese'], ['apple', 'banana', 'butter'], ['apple', 'banana', 'mango'], ['apple', 'grapes', 'milk'], ['apple', 'grapes', 'sugar'], ['apple', 'grapes', 'toast'], ['apple', 'grapes', 'mango'], ['apple', 'curd', 'milk'], ['apple', 'curd', 'sugar'], ['apple', 'curd', 'toast'], ['apple', 'curd', 'grapes'], ['apple', 'curd', 'mango'], ['apple', 'cheese', 'milk'], ['apple', 'cheese', 'sugar'], ['apple', 'cheese', 'toast'], ['apple', 'cheese', 'crisp'], ['apple', 'cheese', 'grapes'], ['apple', 'cheese', 'curd'], ['apple', 'cheese', 'mango'], ['apple', 'butter', 'milk'], ['apple', 'butter', 'sugar'], ['apple', 'butter', 'toast'], ['apple', 'butter', 'crisp'], ['apple', 'butter', 'grapes'], ['apple', 'butter', 'curd'], ['apple', 'butter', 'cheese'], ['apple', 'butter', 'mango'], ['apple', 'mango', 'milk'], ['apple', 'mango', 'sugar'], ['apple', 'mango', 'toast'], ['banana', 'milk', 'sugar'], ['banana', 'milk', 'toast'], ['banana', 'sugar', 'toast'], ['banana', 'bread', 'milk'], ['banana', 'bread', 'sugar'], ['banana', 'bread', 'toast'], ['banana', 'bread', 'crisp'], ['banana', 'bread', 'grapes'], ['banana', 'bread', 'curd'], ['banana', 'bread', 'cheese'], ['banana', 'bread', 'butter'], ['banana', 'bread', 'mango'], ['banana', 'crisp', 'milk'], ['banana', 'crisp', 'sugar'], ['banana', 'crisp', 'toast'], ['banana', 'crisp', 'grapes'], ['banana', 'crisp', 'curd'], ['banana', 'crisp', 'mango'], ['banana', 'grapes', 'milk'], ['banana', 'grapes', 'sugar'], ['banana', 'grapes', 'toast'], ['banana', 'grapes', 'mango'], ['banana', 'curd', 'milk'], ['banana', 'curd', 'sugar'], ['banana', 'curd', 'toast'], ['banana', 'curd', 'grapes'], ['banana', 'curd', 'mango'], ['banana', 'cheese', 'milk'], ['banana', 'cheese', 'sugar'], ['banan ...
# ------------------------------------------------------------------
# ----------------------FREQUENT 4-ITEMSET-------------------------
# [['bread', 'milk', 'sugar', 'toast'], ['bread', 'crisp', 'milk', 'sugar'], ['bread', 'crisp', 'milk', 'toast'], ['bread', 'crisp', 'sugar', 'toast'], ['bread', 'crisp', 'grapes', 'milk'], ['bread', 'crisp', 'grapes', 'sugar'], ['bread', 'crisp', 'grapes', 'toast'], ['bread', 'crisp', 'grapes', 'mango'], ['bread', 'crisp', 'curd', 'milk'], ['bread', 'crisp', 'curd', 'sugar'], ['bread', 'crisp', 'curd', 'toast'], ['bread', 'crisp', 'curd', 'grapes'], ['bread', 'crisp', 'curd', 'mango'], ['bread', 'crisp', 'mango', 'milk'], ['bread', 'crisp', 'mango', 'sugar'], ['bread', 'crisp', 'mango', 'toast'], ['bread', 'grapes', 'milk', 'sugar'], ['bread', 'grapes', 'milk', 'toast'], ['bread', 'grapes', 'sugar', 'toast'], ['bread', 'grapes', 'mango', 'milk'], ['bread', 'grapes', 'mango', 'sugar'], ['bread', 'grapes', 'mango', 'toast'], ['bread', 'curd', 'milk', 'sugar'], ['bread', 'curd', 'milk', 'toast'], ['bread', 'curd', 'sugar', 'toast'], ['b
# ------------------------------------------------------------------
# ----------------------FREQUENT 5-ITEMSET-------------------------
# [['bread', 'crisp', 'milk', 'sugar', 'toast'], ['bread', 'crisp', 'grapes', 'milk', 'sugar'], ['bread', 'crisp', 'grapes', 'milk', 'toast'], ['bread', 'crisp', 'grapes', 'sugar', 'toast'], ['bread', 'crisp', 'grapes', 'mango', 'milk'], ['bread', 'crisp', 'grapes', 'mango', 'sugar'], ['bread', 'crisp', 'grapes', 'mango', 'toast'], ['bread', 'crisp', 'curd', 'milk', 'sugar'], ['bread', 'crisp', 'curd', 'milk', 'toast'], ['bread', 'crisp', 'curd', 'sugar', 'toast'], ['bread', 'crisp', 'curd', 'grapes', 'milk'], ['bread', 'crisp', 'curd', 'grapes', 'sugar'], ['bread', 'crisp', 'curd', 'grapes', 'toast'], ['bread', 'crisp', 'curd', 'grapes', 'mango'], ['bread', 'crisp', 'curd', 'mango', 'milk'], ['bread', 'crisp', 'curd', 'mango', 'sugar'], ['bread', 'crisp', 'curd', 'mango', 'toast'], ['bread', 'crisp', 'mango', 'milk', 'sugar'], ['bread', 'crisp', 'mango', 'milk', 'toast'], ['bread', 'crisp', 'mango', 'sugar', 'toast'], ['bread', 'grapes', 'milk', 'sugar', 'toast'], ['bread', 'grapes', 'mango', 'milk', 'sugar'], ['bread', 'grapes', 'mango', 'milk', 'toast'], ['bread', 'grapes', 'mango', 'sugar', 'toast'], ['bread', 'curd', 'milk', 'sugar', 'toast'], ['bread', 'curd', 'grapes', 'milk', 'sugar'], ['bread', 'curd', 'grapes', 'milk', 'toast'], ['bread', 'curd', 'grapes', 'sugar', 'toast'], ['bread', 'curd', 'grapes', 'mango', 'milk'], ['bread', 'curd', 'grapes', 'mango', 'sugar'], ['bread', 'curd', 'grapes', 'mango', 'toast'], ['bread', 'curd', 'mango', 'milk', 'sugar'], ['bread', 'curd', 'mango', 'milk', 'toast'], ['bread', 'curd', 'mango', 'sugar', 'toast'], ['bread', 'cheese', 'milk', 'sugar', 'toast'], ['bread', 'cheese', 'crisp', 'milk', 'sugar'], ['bread', 'cheese', 'crisp', 'milk', 'toast'], ['bread', 'cheese', 'crisp', 'sugar', 'toast'], ['bread', 'cheese', 'crisp', 'grapes', 'milk'], ['bread', 'cheese', 'crisp', 'grapes', 'sugar'], ['bread', 'cheese', 'crisp', 'grapes', 'toast'], ['bread', 'cheese', 'crisp', 'grapes', 'mango'], ['bread', 'cheese', 'crisp', 'curd', 'milk'], ['bread', 'cheese', 'crisp', 'curd', 'sugar'], ['bread', 'cheese', 'crisp', 'curd', 'toast'], ['bread', 'cheese', 'crisp', 'curd', 'grapes'], ['bread', 'cheese', 'crisp', 'curd', 'mango'], ['bread', 'cheese', 'crisp', 'mango', 'milk'], ['bread', 'cheese', 'crisp', 'mango', 'sugar'], ['bread', 'cheese', 'crisp', 'mango', 'toast'], ['bread', 'cheese', 'grapes', 'milk', '
 'mango', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'cheese', 'crisp', 'grapes', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'cheese', 'crisp', 'grapes', 'mango', 'milk', 'sugar'], ['apple', 'bread', 'cheese', 'crisp', 'grapes', 'mango', 'milk', 'toast'], ['apple', 'bread', 'cheese', 'crisp', 'grapes', 'mango', 'sugar', 'toast'], ['apple', 'bread', 'cheese', 'crisp', 'curd', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'cheese', 'crisp', 'curd', 'grapes', 'milk', 'sugar'], ['apple', 'bread', 'cheese', 'crisp', 'curd', 'grapes', 'milk', 'toast'], ['apple', 'bread', 'cheese', 'crisp', 'curd', 'grapes', 'sugar', 'toast'], ['apple', 'bread', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk'], ['apple', 'bread', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'sugar'], ['apple', 'bread', 'cheese', 'crisp', 'curd', 'gr ...
# ------------------------------------------------------------------
# ----------------------FREQUENT 9-ITEMSET-------------------------
# [['bread', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['bread', 'butter', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['bread', 'butter', 'cheese', 'crisp', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'milk', 'sugar', 'toast'], ['bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar'], ['bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'toast'], ['bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'sugar', 'toast'], ['bread', 'butter', 'cheese', 'crisp', 'curd', 'mango', 'milk', 'sugar', 'toast'], ['bread', 'butter', 'cheese', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'cheese', 'crisp', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'cheese', 'crisp', 'curd', 'grapes', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar'], ['apple', 'bread', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'toast'], ['apple', 'bread', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'sugar', 'toast'], ['apple', 'bread', 'cheese', 'crisp', 'curd', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'cheese', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'crisp', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'crisp', 'curd', 'grapes', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar'], ['apple', 'bread', 'butter', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'toast'], ['apple', 'bread', 'butter', 'crisp', 'curd', 'grapes', 'mango', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'crisp', 'curd', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'grapes', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'grapes', 'mango', 'milk', 'sugar'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'grapes', 'mango', 'milk', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'grapes', 'mango', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'milk', 'sugar'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'milk', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'sugar'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'mango', 'milk', 'sugar'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'mango', 'milk', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'mango', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'curd', 'grapes', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'curd', 'grapes', 'mango', 'milk', 'sugar'], ['apple', 'bread', 'butter', 'cheese', 'curd', 'grapes', 'mango', 'milk', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'curd', 'grapes', 'mango', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'curd', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'crisp', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'crisp', 'curd', 'grapes', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'crisp', 'curd', 'grapes', 'mang ...
# ------------------------------------------------------------------
# ----------------------FREQUENT 10-ITEMSET-------------------------
# [['bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'bread', 'butter', 'cheese', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'cheese', 'crisp', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'cheese', 'crisp', 'curd', 'grapes', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar'], ['apple', 'banana', 'bread', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'toast'], ['apple', 'banana', 'bread', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'cheese', 'crisp', 'curd', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'cheese', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'crisp', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'crisp', 'curd', 'grapes', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar'], ['apple', 'banana', 'bread', 'butter', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'toast'], ['apple', 'banana', 'bread', 'butter', 'crisp', 'curd', 'grapes', 'mango', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'crisp', 'curd', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'grapes', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'grapes', 'mango', 'milk', 'sugar'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'grapes', 'mango', 'milk', 'toast'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'grapes', 'mango', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'milk', 'sugar'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'milk', 'toast'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'sugar'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'toast'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'mango', 'milk', 'sugar'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'mango', 'milk', 'toast'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'mango', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'curd', 'grapes', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'curd', 'grapes', 'ma ...
# ------------------------------------------------------------------
# ----------------------FREQUENT 11-ITEMSET-------------------------
# [['apple', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'toast'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'bread', 'butter', 'cheese', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['apple', 'banana', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast'], ['banana', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast']]
# ------------------------------------------------------------------
# ----------------------FREQUENT 12-ITEMSET-------------------------
# [['apple', 'banana', 'bread', 'butter', 'cheese', 'crisp', 'curd', 'grapes', 'mango', 'milk', 'sugar', 'toast']]
# ------------------------------------------------------------------
# ----------------------FREQUENT 13-ITEMSET-------------------------
# []
# ------------------------------------------------------------------
# --------------------ASSOCIATION RULES-------------------
#
# RULE 	 	 	       SUPP      CONF      LIFT
# --------------------------------------------------------
# --------------------------------------------------------
